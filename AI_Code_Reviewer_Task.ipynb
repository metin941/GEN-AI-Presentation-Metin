# %% [markdown]
# # 🤖 AI Code Reviewer — Задача
#
# В тази задача ще създадеш опростен **AI**, който се преструва на програмен "ревюър" — оценява качеството на дадено Python парче код.
#
# Целта е да използваш твоята логика (или въображаемата логика на AI), за да решиш:
# - Дали кодът е "добър"
# - Или "може да се подобри"
#
# AI може да гледа за:
# - Дали има дефиниция на функция (`def`)
# - Дали има коментари (`#`)
# - Дали се използват смислени имена на променливи
# - Или просто дали изглежда "умно" 🤓
#
# Да започваме!

# %%
def ai_code_reviewer(code_snippet: str) -> str:
    """
    Тази функция приема текстов Python код (като string)
    и връща дали AI смята, че е 'Добър код' или 'Може да се подобри'.

    Можеш да използваш различни критерии:
    - Дали съдържа "def"
    - Дали използва коментари
    - Дали е прекалено дълъг или кратък
    - Дали използва смислени имена на променливи (напр. не 'x', 'y')
    """

    # 👉 Напиши своя "AI алгоритъм" тук
    if "def" in code_snippet and "#" in code_snippet:
        return "AI казва: Добър код! 🤖👍"
    else:
        return "AI казва: Може да се подобри... 🤔"

# %%
# 🧪 Тествай своя "AI"
my_code = '''
def greet():
    # Поздравява потребителя
    print("Здрасти!")
'''

print(ai_code_reviewer(my_code))
